# %% [markdown]
# <div style="text-align: center">
#
# # **AMCAT Analyis**
#
# </div>

# %% [markdown]
# ## Data Summary 📋
#
# Aspiring Minds made the dataset from the Aspiring Mind Employment Outcome 2015 (AMEO) available. Students specializing in engineering are the only ones eligible to participate in the study. The dataset includes three dependent variables (salary, job titles, and job locations) related to the employment outcomes of engineering graduates in addition to standardized scores from three distinct skill categories: technical skills, cognitive skills, and personality skills. There are demographic features in the dataset as well. There are about 4000 data points and 40 independent variables in the dataset. Both continuous and categorical variables make up the independent variables. Every candidate has a distinct identification in the dataset. The details for the original dataset are shown in the table below.

# %% [markdown]
# ## **Problem Statement**
#
# The goal of this project is to analyze AMCAT data to identify the key factors influencing salary variations across different groups. Specifically, we aim to determine which categories of individuals are earning higher salaries and which groups are earning lower salaries. By examining variables such as education, occupation, experience, location, and demographics, we seek to understand the primary drivers behind income disparities.

# %% [markdown]
# ### Column description:
# - **ID :** A unique ID to identify a candidate
# - **Salary :** Annual CTC oﬀered to the candidate (in INR)
# - **DOJ :** Date of joining the company
# - **DOL :** Date of leaving the company
# - **Designation :** Designation oﬀered in the job
# - **JobCity :** Location of the job (city)
# - **Gender :** Candidate's gender
# - **DOB :** Date of birth of the candidate
# - **10percentage :** Overall marks obtained in grade 10 examinations
# - **10board :** The school board whose curriculum the candidate followed in grade 10
# - **12graduation :** Year of graduation - senior year high school
# - **12percentage :** Overall marks obtained in grade 12 examinations
# - **12board :** The school board whose curriculum the candidate followed in grade 12
# - **CollegeID :** Unique ID identifying the college which the candidate attended
# - **CollegeTier :** Tier of college
# - **Degree :** Degree obtained/pursued by the candidate
# - **Specialization :** Specialization pursued by the candidate
# - **CollegeGPA :** Aggregate GPA at graduation
# - **CollegeCityID :** A unique ID to identify the city in which the college is located in
# - **CollegeState :**  The tier of the city in which the college is located
# - **CollegeState :** Name of States
# - **GraduationYear :** Year of graduation (Bachelor’s degree)
# - **English :** Scores in AMCAT English section
# - **Logical :** Scores in AMCAT Logical section
# - **Quant :** Scores in AMCAT Quantitative section
# - **Domain :** Scores in AMCAT’s domain module
# - **ComputerProgramming :** Score in AMCAT’s Computer programming section
# - **ElectronicsAndSemicon :** Score in AMCAT’s Electronics & Semiconductor Engineering section
# - **ComputerScience :** Score in AMCAT’s Computer Science section
# - **MechanicalEngg :** Score in AMCAT’s Mechanical Engineeringsection
# - **ElectricalEngg :** Score in AMCAT’s Electrical Engineering section
# - **TelecomEngg :** Score in AMCAT’s Telecommunication Engineering section
# - **CivilEngg :** Score in AMCAT’s Civil Engineering section
# - **conscientiousness :** Scores in one of the sections of AMCAT’s personality test
# - **agreeableness:** Scores in one of the sections of AMCAT’s personality test
# - **extraversion :** Scores in one of the sections of AMCAT’s personality test
# - **neuroticism :** Scores in one of the sections of AMCAT’s personality test
# - **openess_to_experience :** Scores in one of the sections of AMCAT’s personality test

# %% [markdown]
# ### **Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading Dataset

# %%
df = pd.read_csv(r"C:\Users\shiva\Downloads\data.xlsx - Sheet1.csv")
df.drop("Unnamed: 0", axis = 1, inplace =True)
df.head()
# Out:
#        ID     Salary          DOJ          DOL               Designation  \
# 0  203097   420000.0  6/1/12 0:00      present   senior quality engineer
# 1  579905   500000.0  9/1/13 0:00      present         assistant manager
# 2  810601   325000.0  6/1/14 0:00      present          systems engineer
# 3  267447  1100000.0  7/1/11 0:00      present  senior software engineer
# 4  343523   200000.0  3/1/14 0:00  3/1/15 0:00                       get
#
#      JobCity Gender           DOB  10percentage  \
# 0  Bangalore      f  2/19/90 0:00          84.3
# 1     Indore      m  10/4/89 0:00          85.4
# 2    Chennai      f   8/3/92 0:00          85.0
# 3    Gurgaon      m  12/5/89 0:00          85.6
# 4    Manesar      m  2/27/91 0:00          78.0
#
#                           10board  ...  ComputerScience  MechanicalEngg  \
# 0  board ofsecondary education,ap  ...               -1              -1
# 1                            cbse  ...               -1              -1
# ...

# %%
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3998 entries, 0 to 3997
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     3998 non-null   int64
#  1   Salary                 3998 non-null   float64
#  2   DOJ                    3998 non-null   object
#  3   DOL                    3998 non-null   object
#  4   Designation            3998 non-null   object
#  5   JobCity                3998 non-null   object
#  6   Gender                 3998 non-null   object
#  7   DOB                    3998 non-null   object
#  8   10percentage           3998 non-null   float64
#  9   10board                3998 non-null   object
#  10  12graduation           3998 non-null   int64
#  11  12percentage           3998 non-null   float64
#  12  12board                3998 non-null   object
#  13  CollegeID              3998 non-null   int64
# ...

# %%
df.describe(include="object")
# Out:
#                 DOJ      DOL        Designation    JobCity Gender          DOB 10board 12board       Degree                             Specialization   CollegeState
# count          3998     3998               3998       3998   3998         3998    3998    3998         3998                                       3998           3998
# unique           81       67                419        339      2         1872     275     340            4                                         46             26
# top     7/1/14 0:00  present  software engineer  Bangalore      m  1/1/91 0:00    cbse    cbse  B.Tech/B.E.  electronics and communication engineering  Uttar Pradesh
# freq            199     1875                539        627   3041           11    1395    1400         3700                                        880            915

# %%
df.describe(exclude="object")
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage     CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  GraduationYear      English      Logical        Quant       Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  TelecomEngg    CivilEngg  conscientiousness  agreeableness  extraversion  nueroticism  openess_to_experience
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000     3998.000000  3998.000000  3998.000000  3998.000000  3998.000000          3998.000000            3998.000000      3998.000000     3998.000000     3998.000000  3998.000000  3998.000000        3998.000000    3998.000000   3998.000000  3998.000000            3998.000000
# ...

# %%
### Printing no.of unique elements in each column

for i in df.columns.values:
    print(f"                     column = {i}                 ")
    print()
    print("nunique = ",df[i].nunique())
    print()
    print("unique = \n\n",df[i].unique())
    print()
    print("---"*20)
    print()
# Out:
#                      column = ID
#
# nunique =  3998
#
# unique =
#
#  [203097 579905 810601 ... 355888 947111 324966]
#
# ------------------------------------------------------------
#
#                      column = Salary
#
# nunique =  177
#
# unique =
#
#  [ 420000.  500000.  325000. 1100000.  200000.  300000.  400000.  600000.
#   230000.  450000.  270000.  350000.  250000.  120000.  320000.  190000.
#   180000.  335000.  435000.  345000.  145000.  220000.  530000.  340000.
#   360000.  215000.   80000.  330000.  380000.  110000.  205000.   95000.
#   390000.   60000.  240000.  525000.  305000.  150000.  310000.  455000.
#   800000.  100000.  280000.  445000.  315000.  370000.  275000. 1500000.
#   425000.  470000.  460000.  510000.  480000.  170000.  640000.  225000.
#   440000. 1200000.  675000.  105000.  195000.  385000.  235000.  615000.
#   290000.  140000.  405000. 1860000.  375000.  430000.  660000.   70000.
# ...

# %%
df.shape
# Out:
# (3998, 38)

# %% [markdown]
# ## Converting Date columns into datetime dtype

# %%
def Prst(x):
    if x == "present":
        return 10/6/2024
    else:
        return x

# %%
# Converting date columns into datetime 

print("Type of DOJ column = ",df["DOJ"].dtype)
df["DOJ"] = pd.to_datetime(df["DOJ"])

print("Type of DOJ column = ",df["DOJ"].dtype)
print()
print("Type of DOL column = ",df["DOL"].dtype)
df["DOL"] = df["DOL"].apply(lambda x: Prst(x))
df["DOL"] = pd.to_datetime(df["DOL"])
print("Type of DOJ column = ",df["DOJ"].dtype)
print()
print("Type of DOB column = ",df["DOB"].dtype)
df["DOB"] = pd.to_datetime(df["DOB"])
print("Type of DOJ column = ",df["DOJ"].dtype)
# Out:
# Type of DOJ column =  object
# Type of DOJ column =  datetime64[ns]
#
# Type of DOL column =  object
# Type of DOJ column =  datetime64[ns]
#
# Type of DOB column =  object
# Type of DOJ column =  datetime64[ns]
# C:\Users\shiva\AppData\Local\Temp/ipykernel_29032/1399061311.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["DOJ"] = pd.to_datetime(df["DOJ"])
# C:\Users\shiva\AppData\Local\Temp/ipykernel_29032/1399061311.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["DOB"] = pd.to_datetime(df["DOB"])

# %%
pd.to_datetime(df["DOJ"]).dt.date
# Out:
# 0       2012-06-01
# 1       2013-09-01
# 2       2014-06-01
# 3       2011-07-01
# 4       2014-03-01
#            ...
# 3993    2011-10-01
# 3994    2013-07-01
# 3995    2013-07-01
# 3996    2014-07-01
# 3997    2013-02-01
# Name: DOJ, Length: 3998, dtype: object

# %% [markdown]
# ## Correcting mispelled word

# %%
# Uniforming the JobCity values

df['JobCity'] = df['JobCity'].replace('-1', 'unknown')
df['JobCity'] = df['JobCity'].str.lower()
df['JobCity'] = df['JobCity'].str.strip()

# %%
# Dictionary to update incorrect city names

city_dict_update = {'bangalore': 'banglore',
                    'banaglore': 'banglore',
                    'nouda': 'noida', 
                    'bhubaneshwar': 'bhuvaneswar', 
                    'bhubneshwar': 'bhuvaneswar',
                    'gajiabaad': 'ghaziabad', 
                    'gurga': 'gurgaon', 
                    'vizag': 'visakhapatnam',
                    'gandhi nagar': 'gandhinagar',
                    'kochi/cochin': 'kochi',
                    'calicut': 'kozhikode', 
                    'sonepat': 'sonipat',
                    'nasikcity': 'nashik',
                    'tirupathi': 'tirupati','raipur': 'raipur', 
                    'dhanbad': 'dhanbad',                    
                    'miryalaguda': 'hyderabad',
                    'trichy': 'tiruchirappalli',
                    'secunderabad': 'hyderabad',
                    'rayagada, odisha': 'rayagada',
                    'keral': 'kerala',
                    'latur (maharashtra)': 'latur',
                    'rayagada, odisha':'rayagad',
                    'a-64,sec-64,noida':'noida',
                    'miryalaguda':'hyderabad',    
}

df['JobCity'] = df['JobCity'].str.lower().replace(city_dict_update)
df['JobCity'].value_counts()
# Out:
# JobCity
# banglore            680
# unknown             461
# noida               391
# hyderabad           372
# pune                327
#                    ...
# ambala city           1
# karad                 1
# rajpura               1
# haryana               1
# asifabadbanglore      1
# Name: count, Length: 217, dtype: int64

# %%
# Create a dictionary to map specializations to standardized branch names

specialization_to_branch = {
    'electronics and communication engineering': 'ECE',
    'electronics & telecommunications': 'ECE',
    'electronics and instrumentation engineering': 'ECE',
    'electronics engineering': 'ECE',
    'applied electronics and instrumentation': 'ECE',
    'electronics and computer engineering': 'ECE',
    'telecommunication engineering': 'ECE',
    'electronics & instrumentation eng': 'ECE',
    'electronics': 'ECE',
    
    'computer science & engineering': 'CSE',
    'computer engineering': 'CSE',
    'information technology': 'CSE',
    'computer application': 'General',
    'information science engineering': 'CSE',
    'computer science and technology': 'CSE',
    'computer and communication engineering': 'CSE',
    'computer science': 'CSE',
    'computer networking': 'CSE',
    'embedded systems technology': 'CSE',
    
    'mechanical engineering': 'Mechanical',
    'mechanical and automation': 'Mechanical',
    'mechanical & production engineering': 'Mechanical',
    'automobile/automotive engineering': 'Mechanical',
    'mechatronics': 'Mechanical',
    'aeronautical engineering': 'Mechanical',
    'ceramic engineering': 'Mechanical',
    'metallurgical engineering': 'Mechanical',
    'internal combustion engine': 'Mechanical',
    'power systems and automation': 'Mechanical',
    
    'information technology': 'IT',
    'information science engineering': 'IT',
    'information & communication technology': 'IT',
    
    'electrical engineering': 'EEE',
    'electronics and electrical engineering': 'EEE',
    'electrical and power engineering': 'EEE',
    
    'instrumentation and control engineering': 'Instrumentation',
    'instrumentation engineering': 'Instrumentation',
    'control and instrumentation engineering': 'Instrumentation',
    
    'civil engineering': 'Civil',
    
    'biotechnology': 'Biotechnology',
    'biomedical engineering': 'Biotechnology',
    
    'industrial & production engineering': 'Industrial & Production',
    'industrial engineering': 'Industrial & Production',
    'industrial & management engineering': 'Industrial & Production',
    
    'chemical engineering': 'Chemical',
    'polymer technology': 'Chemical',
    
    'other': 'Other'
}

# Convert the specialization column to lowercase for standardization
df['Specialization'] = df['Specialization'].str.lower()

# Map the specializations to the corresponding branches
df['Branch'] = df['Specialization'].map(specialization_to_branch)

# %%
# Modifyung gender values
gender_dict_update = {'m':'Male',
                      'f':'Female'
}
df['Gender'] = df['Gender'].replace(gender_dict_update)

# %% [markdown]
# # Univariate Analysis

# %%
df_num = df.select_dtypes(["int","float"])
df_cat = df.select_dtypes("object")
df_date = df.select_dtypes("datetime64[ns]")
print("No.of numerical columns = ",df_num.shape[1])
print("No.of object columns = ",df_cat.shape[1])
print("No.of date columns = ",df_date.shape[1])
# Out:
# No.of numerical columns =  27
# No.of object columns =  9
# No.of date columns =  3

# %% [markdown]
# ### 1) Numerical Columns

# %%
df_num.head()
# Out:
#        ID     Salary  10percentage  12graduation  12percentage  CollegeID  CollegeTier  collegeGPA  CollegeCityID  CollegeCityTier  GraduationYear  English  Logical  Quant    Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  agreeableness  extraversion  nueroticism  openess_to_experience
# 0  203097   420000.0          84.3          2007          95.8       1141            2       78.00           1141                0            2011      515      585    525  0.635979                  445                     -1               -1              -1              -1           -1         -1             0.9737         0.8128        0.5269      1.35490                -0.4455
# ...

# %%
df_num.describe(include = ["int","float"])
# Out:
#                  ID        Salary  10percentage  12graduation  12percentage     CollegeID  CollegeTier   collegeGPA  CollegeCityID  CollegeCityTier  GraduationYear      English      Logical        Quant       Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  TelecomEngg    CivilEngg  conscientiousness  agreeableness  extraversion  nueroticism  openess_to_experience
# count  3.998000e+03  3.998000e+03   3998.000000   3998.000000   3998.000000   3998.000000  3998.000000  3998.000000    3998.000000      3998.000000     3998.000000  3998.000000  3998.000000  3998.000000  3998.000000          3998.000000            3998.000000      3998.000000     3998.000000     3998.000000  3998.000000  3998.000000        3998.000000    3998.000000   3998.000000  3998.000000            3998.000000
# ...

# %%
# Set the number of columns for the subplots
n_cols = 3  
n_rows = (len(df_num.columns) + n_cols - 1) // n_cols  # Calculate the number of rows needed

# Create a figure with subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, 5 * n_rows))
axes = axes.flatten()  # Flatten the axes array for easy indexing

# Iterate through the columns in the DataFrame
for idx, col in enumerate(df_num.columns):
    # Use seaborn's histplot to plot histogram and KDE on the corresponding subplot
    sns.histplot(df_num[col], kde=True, color="lightblue", edgecolor='black', alpha=0.7, bins=10, ax=axes[idx])

    # Set labels and title for each subplot
    axes[idx].set_xlabel(col)
    axes[idx].set_ylabel('Count')  # Y-axis for counts
    axes[idx].set_title(f'Histogram and Density Curve of {col}')

    # Add mean and median lines
    axes[idx].axvline(df_num[col].mean(), color='red', linestyle='dashed', linewidth=1, label='Mean')
    axes[idx].axvline(df_num[col].median(), color='orange', linestyle='dashed', linewidth=1, label='Median')
    axes[idx].legend()

# Remove empty subplots if any
for j in range(idx + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()  # Show all plots

# %% [markdown]
# ### Inference:
#
# - **ID**: The ID values range from approximately 11,244 to 1,298,275, with a mean of 663,794, suggesting a wide variation in IDs assigned, possibly indicating a unique identification system across a large dataset with nearly 4,000 entries.
# - **Salary**: The salary distribution is heavily right-skewed, indicating that while most salaries are clustered around the lower end, there are a few high earners significantly increasing the mean.
#
# - **10percentage**: The school board whose curriculum the candidate followed in grade 10 shows varying proportions of students, suggesting differences in educational quality or curriculum among boards.
#
# - **12graduation**: Year of graduation indicates a broad range from 1995 to 2013, with a central tendency around 2008, reflecting a significant number of graduates in that period.
#
# - **12percentage**: Overall marks obtained in grade 12 examinations show most students scoring between 66% and 82%, with a noticeable peak around the mean of 74.5%.
#
# - **CollegeID**: This variable indicates varying representation among colleges, hinting at potential biases in data from certain institutions.
#
# - **CollegeTier**: The distribution likely reflects a higher frequency of students attending lower-tier colleges, suggesting a trend towards less prestigious institutions.
#
# - **collegeGPA**: The GPA data displays a tendency towards lower GPAs, with many students falling below the average of around 2.0.
#
# - **CollegeCityID**: Similar to CollegeID, this variable highlights the number of students from various cities, reflecting geographical trends in education.
#
# - **CollegeCityTier**: The distribution might show a higher concentration of students from urban areas, suggesting that city-tier correlates with college attendance.
#
# - **GraduationYear**: The year of graduation indicates a significant number of graduates from the early 2010s, reflecting a cohort of students graduating around that time.
#
# - **English**: The scores for English show concentration around the average, suggesting that many students achieve moderate proficiency in the subject.
#
# - **Logical**: The distribution of logical scores indicates that most students perform at an average level, with fewer students demonstrating extreme logical reasoning capabilities.
#
# - **Quant**: The quant scores are expected to show a normal distribution around the mean, reflecting varying levels of proficiency in quantitative reasoning.
#
# - **Domain**: The scores in domain subjects reveal a mixed distribution, indicating that student proficiency varies significantly across different domains.
#
# - **ComputerProgramming**: The histogram likely indicates a higher frequency of students with low to moderate programming skills, suggesting a need for improvement in this area.
#
# - **ElectronicsAndSemicon**: This variable may show a skewed distribution, reflecting varying interests and expertise levels in electronics and semiconductor subjects.
#
# - **ComputerScience**: The distribution of scores indicates a significant number of students achieving moderate proficiency, suggesting a potential for growth in computer science education.
#
# - **MechanicalEngg**: The scores in mechanical engineering likely indicate a normal distribution, suggesting consistent performance among students in this field.
#
# - **ElectricalEngg**: The histogram may reflect varying levels of proficiency, with a noticeable number of students scoring below the average.
#
# - **TelecomEngg**: The distribution of scores in telecom engineering might show a clustering around the average, indicating moderate overall performance.
#
# - **CivilEngg**: The scores in civil engineering likely exhibit a range, suggesting diverse levels of understanding and skill among students.
#
# - **Conscientiousness**: The conscientiousness scores may show a mixed distribution, reflecting varying levels of diligence and dependability among students.
#
# - **Agreeableness**: This variable likely indicates that most students exhibit moderate agreeableness, with fewer students showing extreme scores.
#
# - **Extraversion**: The distribution of extraversion scores may reflect a tendency towards average levels of sociability among students.
#
# - **Neuroticism**: Scores in neuroticism might show a normal distribution, indicating varying levels of emotional stability among students.
#
# - **Openness_to_experience**: The openness to experience scores may indicate a diverse range of traits, reflecting varying levels of creativity and curiosity among students.

# %% [markdown]
# ### Analyzing outliers with boxplot

# %%
for i, col in enumerate(df_num.columns, 1):
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=df_num, x=col, color="lightblue")
    plt.title(f'Box Plot of {col}')
    plt.ylabel(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Inference:
#
# 1. **ID:** The box plot indicates a wide range of values for IDs, with no significant outliers. This reflects a diverse sample of entities or individuals without any extreme cases.
#
# 2. **Salary:** The box plot reveals a right-skewed distribution with several outliers on the high end, indicating a few individuals with exceptionally high salaries compared to the majority. These outliers may represent high-earning positions or significant career advancements.
#
# 3. **10percentage:** The plot shows a relatively tight interquartile range, with a few outliers on the lower end. The presence of these outliers could signify candidates who struggled academically in grade 10.
#
# 4. **12graduation:** The box plot illustrates a consistent graduation year range, with no significant outliers. This indicates a stable cohort of graduates within the expected timeline.
#
# 5. **12percentage:** The distribution appears moderately spread, with a few high outliers, suggesting that some candidates excelled significantly in their 12th-grade exams compared to others.
#
# 6. **CollegeID:** The plot displays a broad range with no clear outliers, indicating that the dataset encompasses a wide variety of colleges attended by the candidates.
#
# 7. **CollegeTier:** The box plot reveals a concentrated cluster around tier 2, with no extreme outliers. This suggests that most candidates graduated from mid-tier colleges, reflecting a consistent educational background.
#
# 8. **collegeGPA:** The plot shows some outliers, particularly on the lower end, indicating that a few candidates may have struggled academically during college.
#
# 9. **CollegeCityID:** The distribution appears wide but does not have significant outliers. This suggests a varied geographic representation without extreme cases.
#
# 10. **CollegeCityTier:** The box plot indicates a relatively low average tier with no apparent outliers. Most candidates are from lower-tier cities, reflecting the potential socio-economic factors impacting educational opportunities.
#
# 11. **GraduationYear:** The plot shows a steady range of graduation years, with no outliers. This indicates that the dataset consists of a balanced representation of recent graduates.
#
# 12. **English:** The box plot reveals several outliers, particularly on the lower end, indicating candidates who may have faced challenges in English proficiency. These outliers may represent individuals who did not perform well in language-related subjects.
#
# 13. **Logical:** Similar to English, the plot shows a few outliers on the lower end, suggesting candidates with weaker logical reasoning skills, which could affect their performance in analytical tasks.
#
# 14. **Quant:** The distribution appears to be fairly normal, with only a few outliers on the higher end, indicating candidates who excelled in quantitative skills.
#
# 15. **Domain:** The box plot shows a tightly packed range of scores with no significant outliers. Most candidates seem to have moderate knowledge in their specialized domains.
#
# 16. **ComputerProgramming:** The plot reveals a wide range of scores with some outliers on the lower end, suggesting a few candidates may have limited programming skills.
#
# 17. **ElectronicsAndSemicon:** The box plot displays a concentration of scores with a few higher outliers, indicating that some candidates possess advanced knowledge in this field.
#
# 18. **ComputerScience:** The plot shows a similar trend with high scores and some outliers, suggesting proficiency among many candidates but with a few exceptional cases.
#
# 19. **MechanicalEngg:** The distribution shows a high number of low scores, indicating potential difficulty in this subject. A few higher outliers may represent candidates who performed exceptionally well.
#
# 20. **ElectricalEngg:** Similar to Mechanical Engineering, the plot indicates many candidates with low scores and a couple of outliers that performed well, highlighting a challenging subject area.
#
# 21. **TelecomEngg:** The plot shows a moderate spread with a few higher outliers, suggesting that while many candidates performed adequately, some excelled.
#
# 22. **CivilEngg:** The box plot reveals a concentration of low scores, indicating significant challenges in civil engineering subjects, with no clear outliers to suggest exceptional performance.
#
# 23. **conscientiousness:** The distribution shows a few outliers on the negative side, suggesting some candidates have significantly lower conscientiousness, which could impact their work habits.
#
# 24. **agreeableness:** The plot indicates a normal distribution without significant outliers, suggesting a balanced level of agreeableness among candidates.
#
# 25. **extraversion:** The distribution shows a mix of scores but no significant outliers, indicating a stable level of extraversion across the cohort.
#
# 26. **nueroticism:** The plot reveals a slight negative skew with some candidates showing notably low neuroticism, indicating emotional stability.
#
# 27. **openess_to_experience:** The box plot indicates a clustering of lower scores, with no significant outliers, suggesting that most candidates exhibit a traditional mindset.

# %% [markdown]
# ### 2) Categorical Columns

# %%
df_cat.head()
# Out:
#                 Designation   JobCity  Gender                         10board                             12board       Degree                             Specialization    CollegeState Branch
# 0   senior quality engineer  banglore  Female  board ofsecondary education,ap  board of intermediate education,ap  B.Tech/B.E.                       computer engineering  Andhra Pradesh    CSE
# 1         assistant manager    indore    Male                            cbse                                cbse  B.Tech/B.E.  electronics and communication engineering  Madhya Pradesh    ECE
# 2          systems engineer   chennai  Female                            cbse                                cbse  B.Tech/B.E.                     information technology   Uttar Pradesh     IT
# 3  senior software engineer   gurgaon    Male                            cbse                                cbse  B.Tech/B.E.                       computer engineering           Delhi    CSE
# ...

# %%
df_cat.describe(include="object")
# Out:
#               Designation   JobCity Gender 10board 12board       Degree                             Specialization   CollegeState Branch
# count                3998      3998   3998    3998    3998         3998                                       3998           3998   3997
# unique                419       217      2     275     340            4                                         46             26     12
# top     software engineer  banglore   Male    cbse    cbse  B.Tech/B.E.  electronics and communication engineering  Uttar Pradesh    CSE
# freq                  539       680   3041    1395    1400         3700                                        880            915   1355

# %%
# Define the number of rows and columns for subplots
num_columns = len(df_cat.columns)
cols = 3  # 3 columns for subplots
rows = (num_columns // cols) + (num_columns % cols > 0)  # Calculate the number of rows needed

# Create a figure with subplots (3 columns and calculated rows)
fig, axes = plt.subplots(rows, cols, figsize=(15, rows * 5))  # Adjust the figsize as necessary

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, column in enumerate(df_cat.columns):
    A = df_cat[column].value_counts()
    total_count = A.sum()  # Calculate the total count for percentage calculation

    # Dynamically generate the correct number of colors for the palette
    unique_categories = len(A.index[0:10])  # Get the number of unique categories for each column
    palette = sns.color_palette("Paired", unique_categories)  # Generate the correct number of colors

    # Create the bar plot in the corresponding subplot
    bar_plot = sns.barplot(x=A.index[0:10], y=A.values[0:10], ax=axes[i], hue=A.index[0:10], palette=palette, legend=False)

    # Set the y-axis limit to increase the height of the plot
    axes[i].set_ylim(0, max(A.values[0:10]) * 1.5)

    # Adding counts and percentages on top of the bars
    for p in bar_plot.patches:
        count = int(p.get_height())
        percentage = (count / total_count) * 100  # Calculate percentage
        bar_plot.annotate(f'{count}', 
                          (p.get_x() + p.get_width() / 2., p.get_height()), 
                          ha='center', va='bottom', fontsize=12, fontweight="bold", rotation=90)  # Rotate the label

    # Set the title and labels for each subplot
    axes[i].set_title(f'Bar Plot for {column}', fontsize=16, fontweight="bold")
    axes[i].set_xlabel(column, fontsize=14, fontweight="bold")
    axes[i].set_ylabel('Values', fontsize=14, fontweight="bold")
    
    # Set x-ticks with appropriate labels, rotating them by 90 degrees
    axes[i].set_xticks(range(len(A.index[0:10])))  # Set ticks
    axes[i].set_xticklabels(A.index[0:10], rotation=90)  # Rotate x-tick labels to 90 degrees

# Hide any unused subplots if the number of columns is not a perfect multiple of rows
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Inference:
#
# 1. **Designation**: "Software Engineer" stands out as the most frequently mentioned job title, significantly ahead of other roles like Software Developer and System Engineer. This emphasizes a strong focus on software-related positions, with much smaller representation for other technical roles in this portion of the data.
#
# 2. **JobCity**: Bangalore emerges as the leading city for job placements, far ahead of others such as Noida, Hyderabad, and Pune. This highlights Bangalore’s dominance as a tech hub, although other cities also play an important role in providing job opportunities.
#
# 3. **Gender**: The data reveals a clear gender disparity, with male candidates outnumbering female candidates by a large margin. While both genders are represented, the majority of candidates are male, pointing to potential gender imbalances in certain fields.
#
# 4. **10board**: Candidates from CBSE and State Boards form the bulk of this data, indicating that these educational systems are the most prevalent. However, there are several entries marked as "0," which could indicate missing or unverified data.
#
# 5. **12board**: Similar to the 10th board data, CBSE and State Boards dominate the educational backgrounds, reflecting their widespread influence in India’s secondary education. The presence of unverified data ("0") persists here as well.
#
# 6. **Degree**: The B.Tech/B.E. degree overwhelmingly dominates, with a much smaller representation of MCA and M.Tech/M.E. degrees. This indicates that the majority of candidates possess an undergraduate engineering degree, showing the strong preference for technical qualifications in this dataset.
#
# 7. **Specialization**: Among specializations, Electronics and Communication Engineering leads the way, closely followed by Computer Science & Engineering. This suggests a high demand for professionals in electronics and computer-related fields, with other specializations like Mechanical and Electrical Engineering also contributing but to a lesser extent.
#
# 8. **CollegeState**: Uttar Pradesh produces the largest number of candidates, followed by Karnataka and Tamil Nadu. These states appear to have a strong educational infrastructure, contributing significantly to the pool of job applicants in technical fields.
#
# 9. **Branch**: Computer Science and Engineering (CSE) is the most frequently pursued branch of study, followed by Electronics and Communication Engineering (ECE). This trend highlights a strong preference for IT and electronics-related fields, with other branches like Mechanical Engineering and Civil Engineering seeing less representation.

# %% [markdown]
# ### 3) Date time columns:

# %%
df_date.describe()
# Out:
#                                  DOJ                            DOL                            DOB
# count                           3998                           3998                           3998
# mean   2013-07-02 11:04:10.325162496  1993-08-27 07:14:01.020510208  1990-12-06 06:01:15.637819008
# min              1991-06-01 00:00:00            1970-01-01 00:00:00            1977-10-30 00:00:00
# 25%              2012-10-01 00:00:00            1970-01-01 00:00:00            1989-11-16 06:00:00
# 50%              2013-11-01 00:00:00            2012-08-01 00:00:00            1991-03-07 12:00:00
# 75%              2014-07-01 00:00:00            2015-01-01 00:00:00            1992-03-13 18:00:00
# max              2015-12-01 00:00:00            2015-12-01 00:00:00            1997-05-27 00:00:00

# %%
num_columns = len(df_date.columns)
cols = 3  # Number of columns for subplots
rows = (num_columns + cols - 1) // cols  # Calculate number of rows needed

# Create a figure with subplots
fig, axes = plt.subplots(rows, cols, figsize=(20, rows * 5))

# Flatten the axes array for easy iteration
axes = axes.flatten()

for i, column in enumerate(df_date.columns):
    A = df_date[column].dt.date.value_counts()
    
    # Dynamically generate the correct number of colors for the palette
    unique_categories = len(A.index[0:10])  # Get the number of unique categories for each column
    palette = sns.color_palette("Paired", unique_categories)  # Generate the correct number of colors

    # Create the bar plot in the corresponding subplot
    bar_plot = sns.barplot(x=A.index[0:10], y=A.values[0:10], ax=axes[i], hue=A.index[0:10], palette=palette, legend=False)

    # Adding counts on top of the bars
    for p in bar_plot.patches:
        bar_plot.annotate(f'{int(p.get_height())}', 
                          (p.get_x() + p.get_width() / 2., p.get_height()), 
                          ha='center', va='bottom', fontsize=12, fontweight="bold")

    # Set the title and labels for each subplot
    axes[i].set_title(f'Bar Plot for {column}', fontsize=16, fontweight="bold")
    axes[i].set_xlabel(column, fontsize=14, fontweight="bold")
    axes[i].set_ylabel('Values', fontsize=14, fontweight="bold")
    
    # Set x-ticks with appropriate labels
    axes[i].set_xticks(range(len(A.index[0:10])))  # Set ticks
    axes[i].set_xticklabels(A.index[0:10], rotation=90)  # Set labels with rotation

# Hide any unused subplots if the number of columns is not a perfect multiple of rows
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Inference:
#
# 1. **DOJ (Date of Joining)**: The majority of employees joined around mid-2014, particularly on July 1, indicating a peak recruitment period during that time, while the range of joining dates extends from 1991 to 2015, reflecting a mix of new hires and potential outliers.
#
# 2. **DOL (Date of Leaving)**: A high occurrence of January 1, 1970, suggests missing data, but aside from this, the most common leaving date is April 1, 2015, indicating a potential wave of departures or contract completions during early 2015.
#
# 3. **DOB (Date of Birth)**: Most employees were born in 1991, particularly on January 1, suggesting a concentration of individuals in their early 30s, which characterizes a relatively young workforce.

# %% [markdown]
# ## Bivariate Analysis of Salary, Gender, and Academic Background

# %%
df.columns.values
# Out:
# array(['ID', 'Salary', 'DOJ', 'DOL', 'Designation', 'JobCity', 'Gender',
#        'DOB', '10percentage', '10board', '12graduation', '12percentage',
#        '12board', 'CollegeID', 'CollegeTier', 'Degree', 'Specialization',
#        'collegeGPA', 'CollegeCityID', 'CollegeCityTier', 'CollegeState',
#        'GraduationYear', 'English', 'Logical', 'Quant', 'Domain',
#        'ComputerProgramming', 'ElectronicsAndSemicon', 'ComputerScience',
#        'MechanicalEngg', 'ElectricalEngg', 'TelecomEngg', 'CivilEngg',
#        'conscientiousness', 'agreeableness', 'extraversion',
#        'nueroticism', 'openess_to_experience', 'Branch'], dtype=object)

# %%
df.head(2)
# Out:
#        ID    Salary        DOJ        DOL              Designation   JobCity  Gender        DOB  10percentage                         10board  12graduation  12percentage                             12board  CollegeID  CollegeTier       Degree                             Specialization  collegeGPA  CollegeCityID  CollegeCityTier    CollegeState  GraduationYear  English  Logical  Quant    Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  agreeableness  extraversion  nueroticism  openess_to_experience Branch
# ...

# %%
df_num
# Out:
#           ID     Salary  10percentage  12graduation  12percentage  CollegeID  CollegeTier  collegeGPA  CollegeCityID  CollegeCityTier  GraduationYear  English  Logical  Quant    Domain  ComputerProgramming  ElectronicsAndSemicon  ComputerScience  MechanicalEngg  ElectricalEngg  TelecomEngg  CivilEngg  conscientiousness  agreeableness  extraversion  nueroticism  openess_to_experience
# 0     203097   420000.0         84.30          2007         95.80       1141            2       78.00           1141                0            2011      515      585    525  0.635979                  445                     -1               -1              -1              -1           -1         -1             0.9737         0.8128        0.5269      1.35490                -0.4455
# ...

# %% [markdown]
# ### 1. Salary Distribution by Gender

# %%
sns.boxplot(data=df, x='Salary', y='Gender')
# Out:
# <Axes: xlabel='Salary', ylabel='Gender'>

# %% [markdown]
# #### Inference:
# - This boxplot reveals the salary distribution between males and females in the dataset. If there’s a significant difference between the median salaries of men and women, it may indicate a gender pay gap. Pay close attention to the spread (interquartile range) and presence of outliers, which can suggest salary extremes that are higher or lower for a specific gender.
#
# #### For instance:
# - If males generally have higher median salaries, it could reflect either a difference in job roles or negotiating power. Conversely, a lower or similar distribution may highlight greater equality in pay for similar roles.

# %% [markdown]
# ### 2) Salary Distribution by Specialization (Branch of Study)

# %%
plt.figure(figsize=(15, 5))
sns.boxplot(x='Salary', y='Branch', data=df, hue='Branch', palette='Set2', legend=False)
plt.title('Distribution of Salaries by Specialization', fontsize=16)
plt.xlabel('Salary (in currency)', fontsize=12)
plt.ylabel('Branch', fontsize=12)
plt.show()

# %% [markdown]
# ### Inference:
# - This boxplot compares how salaries vary by academic specialization. Engineering branches like CSE (Computer Science Engineering) and IT typically have higher salary ranges, while non-technical fields like Biotechnology or Civil Engineering may show lower median salaries. This highlights the demand and industry differences for each specialization.
#
# ### For example:
# - If CSE or IT graduates are at the higher end of the salary spectrum, it could suggest these fields have better job prospects or higher-paying entry-level jobs compared to traditional branches like Mechanical or Electrical Engineering.

# %% [markdown]
# ### 3. Salary Distribution by College Tier

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(x='CollegeTier', y='Salary', data=df)
plt.title('Salary Distribution by College Tier', fontsize=16)
plt.xlabel('Salary (in currency)', fontsize=12)
plt.ylabel('College Tier', fontsize=12)
plt.show()

# %% [markdown]
# ### Inference:
# - The college tier often influences the initial salary range of graduates. Higher-tier colleges (Tier 1) may have better placement opportunities and partnerships with top-paying companies, which could lead to a higher starting salary for graduates compared to Tier 2 and Tier 3 colleges.
#
# ### Interpretation:
# - If Tier 1 colleges exhibit a significantly higher median salary, it implies that the reputation and quality of the college play a pivotal role in salary determination, even for similar roles.

# %% [markdown]
# ### 4) Distribution of Designations by Gender

# %%
top_20_designations = df['Designation'].value_counts().head(20).index
filtered_df = df[df['Designation'].isin(top_20_designations)]
plt.figure(figsize=(20, 10))
sns.countplot(x='Designation', hue='Gender', data=filtered_df)
plt.title('Count of Designations by Gender', fontsize=16)
plt.xlabel('Designation', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# ### Inference:
# - This countplot shows the distribution of the top 20 job designations across genders. It's useful for identifying potential gender disparities in certain job roles. For example, technical roles such as Software Engineer might have a higher count of male employees, while roles in human resources or design may have more female employees.
#
# ### Key Insight:
# - If there's a clear division in the number of males vs. females across specific designations, this could indicate gender preferences or biases in certain fields, such as males dominating engineering roles and females being more prevalent in management or administrative positions.

# %% [markdown]
# ### 5. College GPA vs Salary

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='collegeGPA', y='Salary')
plt.title('College GPA vs. Salary', fontsize=16)
plt.xlabel('College GPA', fontsize=12)
plt.ylabel('Salary (in Lakhs)', fontsize=12)
plt.show()

# %% [markdown]
# ### Inference:
# - The scatterplot explores the relationship between college GPA and salary. In many cases, a higher GPA could correspond with higher-paying jobs, particularly for technical roles. However, the plot may reveal whether GPA is a weak or strong predictor of salary in this dataset.
#
# ### For example:
# - If there's a positive trend, it suggests that employers place importance on academic performance. If no clear trend is visible, it might imply that other factors, such as skills, college reputation, or interview performance, weigh more heavily in salary determination.

# %% [markdown]
# ### 6. Salary Distribution by Top Job Cities

# %%
top_job_cities = df['JobCity'].value_counts().head(10).index
filtered_df = df[df['JobCity'].isin(top_job_cities)]

plt.figure(figsize=(10, 6))
sns.boxplot(data=filtered_df, x='JobCity', y='Salary', hue='JobCity', palette='Set2', legend=False)
plt.title('Salary Distribution by Job City (Top 10)', fontsize=16)
plt.xlabel('Job City', fontsize=12)
plt.ylabel('Salary (in Lakhs)', fontsize=12)
plt.show()

# %% [markdown]
# ### Inference:
# - Salaries can vary significantly depending on the city. This boxplot helps visualize which cities offer the highest median salaries and which have more variability. Cities like Bangalore or Hyderabad might show higher salary ranges due to being tech hubs, while smaller cities may exhibit lower pay due to fewer opportunities or lower living costs.
#
# ### For instance:
# - If cities like Bangalore or Pune consistently display higher salary ranges, it could highlight the importance of geographic location in salary determination, especially for tech-related jobs.

# %% [markdown]
# ### 7. Correlation Heatmap on Personality Traits

# %%
selected_columns = [  
    'conscientiousness', 'agreeableness', 
    'extraversion', 'nueroticism', 
    'openess_to_experience'
]

filtered_df = df[selected_columns]

correlation_matrix = filtered_df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, linewidths=0.5)

plt.title('Correlation Heatmap on Personality traits', fontsize=20)
plt.show()

# %% [markdown]
# ### Inference:
# - This heatmap visualizes the correlations between different personality traits. A strong positive or negative correlation between traits like conscientiousness and agreeableness may suggest overlapping personality dimensions or opposing traits.
#
# ### Example:
# - If conscientiousness and openness show a low correlation, it might suggest that these are distinct traits that don’t necessarily coexist in the same individual. Conversely, a high correlation between agreeableness and extraversion might indicate that these traits often go hand-in-hand.

# %% [markdown]
# ### 8. Relationship between Gender and Specialization (Branch)

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(df['Gender'], df['Branch'], margins=True)
chi2, p, dof, expected = chi2_contingency(contingency_table.iloc[:-1, :-1])

plt.figure(figsize=(12, 6))
sns.countplot(data=df, y='Branch', hue='Gender', order=df['Branch'].value_counts().index)
plt.title('Distribution of Specialization by Gender', fontsize=16)
plt.xlabel('Specialization', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# ### Inference:
# - The chi-square test checks if there is a statistically significant relationship between gender and specialization. A low p-value (typically <0.05) would suggest that gender preferences significantly affect specialization choices.
#
# ### For instance:
# - If fields like Mechanical or Electrical Engineering have more males and fields like Biotechnology attract more females, the chi-square result would reflect this observed trend.

# %% [markdown]
# ### 9. Testing Salary Claims from Times of India Article (2019)

# %%
relevant_roles = ['program analyst','software engineer', 'hardware engineer', 'associate engineer']
filtered_df = df[df['Designation'].isin(relevant_roles)]

average_salary = filtered_df['Salary'].mean()
median_salary = filtered_df['Salary'].median()

plt.figure(figsize=(10, 5))
sns.boxplot(x='Salary', data=filtered_df)
plt.axvline(2.5, color='red', linestyle='--', label='2.5 Lakhs')
plt.axvline(3.0, color='green', linestyle='--', label='3.0 Lakhs')
plt.title('Salary Distribution for Selected Roles')
plt.xlabel('Salary (in Lakhs)')
plt.legend()
plt.show()

# %% [markdown]
# ### Inference:
# - The article claims that fresh graduates in technical roles like Software Engineer and Associate Engineer can earn between ₹2.5 to ₹3 Lakhs. The average salary from the dataset suggests that most graduates in these roles earn above ₹3 Lakhs, validating the article's statement and even indicating that salaries have improved since the publication.
#
# ### For instance:
# - With an average salary of ₹3.41 Lakhs and a median of ₹3.25 Lakhs, most graduates earn well beyond the lower bound of ₹2.5 Lakhs, which may reflect an upward trend in salary for technical positions.

# %% [markdown]
# # Key Conclusions and Strategic Insights
#
# 1. **Addressing Salary Disparities:**
#    - **Insight:** The analysis highlights a significant gender pay gap, with male candidates earning substantially more than their female counterparts.
#    - **Actionable Strategy:** Implement transparent salary structures and conduct regular pay audits to identify and rectify disparities. Consider mentorship programs to empower female candidates and enhance negotiation skills.
#
# 2. **Leveraging Educational Background:**
#    - **Insight:** Graduates from Tier 1 colleges and those with technical degrees (especially in CSE and IT) command higher salaries, indicating their competitive advantage in the job market.
#    - **Actionable Strategy:** Foster partnerships with educational institutions to create internship and job placement programs. Offer scholarships or training to students from diverse backgrounds to level the playing field.
#
# 3. **Geographic Salary Influences:**
#    - **Insight:** Cities like Bangalore are dominant in offering high salaries, reflecting their status as tech hubs.
#    - **Actionable Strategy:** Consider remote work policies or flexible relocation options to attract talent from high-salary regions while tapping into a broader, diverse talent pool.
#
# 4. **Enhancing Academic Performance Correlation:**
#    - **Insight:** A positive correlation between college GPA and salary suggests that academic excellence can be a predictor of job performance.
#    - **Actionable Strategy:** Integrate academic performance criteria into the recruitment process but balance it with assessments of practical skills and experiences. Consider developing training programs to enhance skills for candidates with lower GPAs.
#
# 5. **Understanding Personality Dynamics:**
#    - **Insight:** Variability in personality traits such as conscientiousness and neuroticism can impact workplace performance and team dynamics.
#    - **Actionable Strategy:** Utilize personality assessments during recruitment to build balanced teams. Tailor management styles and team compositions based on the identified personality traits of employees.
#
# 6. **Promoting Diversity in Specializations:**
#    - **Insight:** The data shows gender biases in specialization choices, with males dominating technical fields.
#    - **Actionable Strategy:** Create targeted outreach initiatives in schools and universities to encourage female students to pursue careers in traditionally male-dominated fields like engineering. Highlight female role models in these areas to inspire the next generation.
#
# 7. **Continuous Monitoring of Gender Representation:**
#    - **Insight:** The workforce reflects a significant gender imbalance, especially in technical roles.
#    - **Actionable Strategy:** Establish diversity targets and monitor progress regularly. Implement training and awareness programs to mitigate biases in hiring and promotion processes.
#
# # Conclusion
# By implementing these strategies, organizations can not only enhance their workplace diversity and inclusivity but also boost overall performance and employee satisfaction. Focusing on equitable practices, educational partnerships, and understanding workforce dynamics will create a more effective and adaptable organization, better equipped to thrive in a competitive landscape.
